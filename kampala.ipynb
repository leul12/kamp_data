# %%
import  pandas as pd
import plotly.express as px

# %% [markdown]
# # Read the `CSV` file which is separated with `;`

# %%
df= pd.read_csv('datas/march_2018_sensor.csv',sep = ';')
df.head()
# Out:
#    sensor_id sensor_type  location    lat     lon  \
# 0         42      SDS011        19  0.323  32.576
# 1         42      SDS011        19  0.323  32.576
# 2         42      SDS011        19  0.323  32.576
# 3         42      SDS011        19  0.323  32.576
# 4         42      SDS011        19  0.323  32.576
#
#                           timestamp   value_type  value
# 0  2018-03-01T00:02:10.425629+00:00           P2  14.20
# 1  2018-03-01T00:02:10.425629+00:00           P1  22.30
# 2  2018-03-01T00:02:11.702777+00:00  temperature  25.20
# 3  2018-03-01T00:02:11.702777+00:00     humidity  61.10
# 4  2018-03-01T00:04:40.249951+00:00           P2  14.07

# %% [markdown]
# ## Get to know the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37590 entries, 0 to 37589
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sensor_id    37590 non-null  int64
#  1   sensor_type  37590 non-null  object
#  2   location     37590 non-null  int64
#  3   lat          37590 non-null  float64
#  4   lon          37590 non-null  float64
#  5   timestamp    37590 non-null  object
#  6   value_type   37590 non-null  object
#  7   value        37590 non-null  float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# # Where it Might be `?`

# %%
fig = px.scatter_mapbox(df, lat=df.lat, lon=df.lon,zoom=6, height=300)
fig.update_layout(
    mapbox_style="white-bg",
    mapbox_layers=[
        {
            "below": 'traces',
            "sourcetype": "raster",
            "sourceattribution": "United States Geological Survey",
            "source": [
                "https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryOnly/MapServer/tile/{z}/{y}/{x}"
            ]
        }
      ])
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
df['value_type'].value_counts()
# Out:
# P2             9499
# P1             9499
# temperature    9296
# humidity       9296
# Name: value_type, dtype: int64

# %%
df['timestamp']= pd.to_datetime(df['timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37590 entries, 0 to 37589
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sensor_id    37590 non-null  int64
#  1   sensor_type  37590 non-null  object
#  2   location     37590 non-null  int64
#  3   lat          37590 non-null  float64
#  4   lon          37590 non-null  float64
#  5   timestamp    37590 non-null  datetime64[ns, UTC]
#  6   value_type   37590 non-null  object
#  7   value        37590 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(3), int64(2), object(2)
# memory usage: 2.3+ MB

# %%
df.loc[0:37589,['timestamp','value_type','value']]
# Out:
#                              timestamp   value_type  value
# 0     2018-03-01 00:02:10.425629+00:00           P2  14.20
# 1     2018-03-01 00:02:10.425629+00:00           P1  22.30
# 2     2018-03-01 00:02:11.702777+00:00  temperature  25.20
# 3     2018-03-01 00:02:11.702777+00:00     humidity  61.10
# 4     2018-03-01 00:04:40.249951+00:00           P2  14.07
# ...                                ...          ...    ...
# 37585 2018-03-21 13:28:25.249357+00:00     humidity  59.00
# 37586 2018-03-21 14:13:01.474358+00:00  temperature  26.20
# 37587 2018-03-21 14:13:01.474358+00:00     humidity  62.20
# 37588 2018-03-21 14:18:00.722787+00:00     humidity  62.40
# 37589 2018-03-21 14:18:00.722787+00:00  temperature  26.20
#
# [37590 rows x 3 columns]

# %% [markdown]
# # let's see the values of humidity and staf during the whole time lapse

# %%
fig = px.line(df, x='timestamp', y='value', color='value_type')
fig.show()

# %% [markdown]
# # prediction
